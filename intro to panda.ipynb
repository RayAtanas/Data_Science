# %%
import pandas as pd

# %%
series = pd.Series(["BMW","HONDA"])
series
# Out:
# 0      BMW
# 1    HONDA
# dtype: object

# %%
colors = pd.Series(["red","green"])
colors
# Out:
# 0      red
# 1    green
# dtype: object

# %%
car_data = pd.DataFrame({"Car Make":series, "Colour":colors})
car_data
# Out:
#   Car Make Colour
# 0      BMW    red
# 1    HONDA  green

# %%
car_sale = pd.read_csv("car-sales.csv")
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sale.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sale.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sale.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00 $5,000.00 $7,000.00 $22,000.00 $3,50...
# dtype: object

# %% [markdown]
# viewing and selecting data

# %%
car_sale.head()
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
animals = pd.Series(["cat", "dog","bird","panda"],
                    index = [0,3,9,3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 3    panda
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    panda
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
 car_sale.groupby(["Make"]).mean()
# Out:
# C:\Users\RayAtanas\AppData\Local\Temp\ipykernel_19092\4252518820.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sale.groupby(["Make"]).mean()
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sale.plot()
# Out:
# <Axes: >

# %%
car_sale.hist()
# Out:
# array([[<Axes: title={'center': 'Odometer (KM)'}>,
#         <Axes: title={'center': 'Doors'}>]], dtype=object)

# %%
car_sale["Price"] = car_sale["Price"].str.replace('[\$\,\.]','').astype(int)
# Out:
# C:\Users\RayAtanas\AppData\Local\Temp\ipykernel_19092\2256970015.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sale["Price"] = car_sale["Price"].str.replace('[\$\,\.]','').astype(int)

# %%
car_sale.hist()
# Out:
# array([[<Axes: title={'center': 'Odometer (KM)'}>,
#         <Axes: title={'center': 'Doors'}>],
#        [<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Peice'}>]], dtype=object)

# %%
car_sale_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sale_missing
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0       NaN
# 8  Toyota  White   60000.0    NaN       NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sale_missing["Odometer"] = car_sale_missing["Odometer"].fillna(car_sale_missing["Odometer"].mean())

# %%
car_sale_missing
# Out:
#      Make Colour       Odometer  Doors     Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0       NaN
# 8  Toyota  White   60000.000000    NaN       NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sale_missing.fillna(car_sale_missing.mean(), inplace = True)
# Out:
# C:\Users\RayAtanas\AppData\Local\Temp\ipykernel_6568\1201065465.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_sale_missing.fillna(car_sale_missing.mean(), inplace = True)

# %%
car_sale_missing
# Out:
#      Make Colour       Odometer  Doors     Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0       NaN
# 8  Toyota  White   60000.000000    4.0       NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sale_missing.dropna(inplace = True)

# %%
car_sale_missing
# Out:
#      Make Colour       Odometer  Doors     Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
seat_column = pd.Series([5,5,5,5,5,5])

# %%
car_sale["Seats"] = seat_column

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats
# 0  Toyota  White         150043      4   $4,000.00     5.0
# 1   Honda    Red          87899      4   $5,000.00     5.0
# 2  Toyota   Blue          32549      3   $7,000.00     5.0
# 3     BMW  Black          11179      5  $22,000.00     5.0
# 4  Nissan  White         213095      4   $3,500.00     5.0
# 5  Toyota  Green          99213      4   $4,500.00     5.0
# 6   Honda   Blue          45698      4   $7,500.00     NaN
# 7   Honda   Blue          54738      4   $7,000.00     NaN
# 8  Toyota  White          60000      4   $6,250.00     NaN
# 9  Nissan  White          31600      4   $9,700.00     NaN

# %%
car_sale["Seats"].fillna(5, inplace = True)

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats
# 0  Toyota  White         150043      4   $4,000.00     5.0
# 1   Honda    Red          87899      4   $5,000.00     5.0
# 2  Toyota   Blue          32549      3   $7,000.00     5.0
# 3     BMW  Black          11179      5  $22,000.00     5.0
# 4  Nissan  White         213095      4   $3,500.00     5.0
# 5  Toyota  Green          99213      4   $4,500.00     5.0
# 6   Honda   Blue          45698      4   $7,500.00     5.0
# 7   Honda   Blue          54738      4   $7,000.00     5.0
# 8  Toyota  White          60000      4   $6,250.00     5.0
# 9  Nissan  White          31600      4   $9,700.00     5.0

# %%
fuel = [5,7.7,7,6.8,5.1,4,5,6,7,8]

# %%
car_sale["Fuel Economy"] = fuel

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel Economy
# 0  Toyota  White         150043      4   $4,000.00     5.0           5.0
# 1   Honda    Red          87899      4   $5,000.00     5.0           7.7
# 2  Toyota   Blue          32549      3   $7,000.00     5.0           7.0
# 3     BMW  Black          11179      5  $22,000.00     5.0           6.8
# 4  Nissan  White         213095      4   $3,500.00     5.0           5.1
# 5  Toyota  Green          99213      4   $4,500.00     5.0           4.0
# 6   Honda   Blue          45698      4   $7,500.00     5.0           5.0
# 7   Honda   Blue          54738      4   $7,000.00     5.0           6.0
# 8  Toyota  White          60000      4   $6,250.00     5.0           7.0
# 9  Nissan  White          31600      4   $9,700.00     5.0           8.0

# %%
car_sale["Total Fuel used"] = car_sale["Odometer (KM)"]/100 * car_sale["Fuel Economy"]

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel Economy  \
# 0  Toyota  White         150043      4   $4,000.00     5.0           5.0
# 1   Honda    Red          87899      4   $5,000.00     5.0           7.7
# 2  Toyota   Blue          32549      3   $7,000.00     5.0           7.0
# 3     BMW  Black          11179      5  $22,000.00     5.0           6.8
# 4  Nissan  White         213095      4   $3,500.00     5.0           5.1
# 5  Toyota  Green          99213      4   $4,500.00     5.0           4.0
# 6   Honda   Blue          45698      4   $7,500.00     5.0           5.0
# 7   Honda   Blue          54738      4   $7,000.00     5.0           6.0
# 8  Toyota  White          60000      4   $6,250.00     5.0           7.0
# 9  Nissan  White          31600      4   $9,700.00     5.0           8.0
#
#    Total Fuel used
# 0         7502.150
# 1         6768.223
# 2         2278.430
# 3          760.172
# 4        10867.845
# 5         3968.520
# 6         2284.900
# ...

# %%
car_sale.hist()
# Out:
# array([[<Axes: title={'center': 'Odometer (KM)'}>,
#         <Axes: title={'center': 'Doors'}>],
#        [<Axes: title={'center': 'Seats'}>,
#         <Axes: title={'center': 'Fuel Economy'}>],
#        [<Axes: title={'center': 'Total Fuel used'}>, <Axes: >]],
#       dtype=object)

# %%
car_sale.plot(
)
# Out:
# <Axes: >

# %%
car_sale["Odometer (KM)"] = car_sale["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel Economy  \
# 0  Toyota  White      93776.875      4   $4,000.00     5.0           5.0
# 1   Honda    Red      54936.875      4   $5,000.00     5.0           7.7
# 2  Toyota   Blue      20343.125      3   $7,000.00     5.0           7.0
# 3     BMW  Black       6986.875      5  $22,000.00     5.0           6.8
# 4  Nissan  White     133184.375      4   $3,500.00     5.0           5.1
# 5  Toyota  Green      62008.125      4   $4,500.00     5.0           4.0
# 6   Honda   Blue      28561.250      4   $7,500.00     5.0           5.0
# 7   Honda   Blue      34211.250      4   $7,000.00     5.0           6.0
# 8  Toyota  White      37500.000      4   $6,250.00     5.0           7.0
# 9  Nissan  White      19750.000      4   $9,700.00     5.0           8.0
#
#    Total Fuel used
# 0         7502.150
# 1         6768.223
# 2         2278.430
# 3          760.172
# 4        10867.845
# 5         3968.520
# 6         2284.900
# ...
