# %%
import pandas as pd 
import numpy as np

# %%
ds = pd.read_csv("Diseases_symptoms.csv")

# %%
ds
# Out:
#                                       Disease               Symptom  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom.1              Symptom.2                  Symptom.3  \
# ...

# %%
ds.dropna(axis = 1 ,how = 'all', inplace = True)

# %%
ds
# Out:
#                                       Disease               Symptom  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom.1              Symptom.2                  Symptom.3  \
# ...

# %%
# Out:
#           Disease               Symptom Symptom.1 Symptom.2 Symptom.3  \
# 260   Common Cold   continuous_sneezing    chills   fatigue     cough
# 261   Common Cold   continuous_sneezing    chills   fatigue     cough
# 670   Common Cold   continuous_sneezing    chills   fatigue     cough
# 671   Common Cold   continuous_sneezing    chills   fatigue     cough
# 1080  Common Cold   continuous_sneezing    chills   fatigue     cough
# ...           ...                   ...       ...       ...       ...
# 4741  Common Cold   continuous_sneezing    chills   fatigue     cough
# 4782  Common Cold   continuous_sneezing    chills   fatigue     cough
# 4823  Common Cold   continuous_sneezing    chills   fatigue     cough
# 4864  Common Cold   continuous_sneezing    chills   fatigue     cough
# 4905  Common Cold   continuous_sneezing    chills   fatigue     cough
#
#         Symptom.4  Symptom.5             Symptom.6 Symptom.7 Symptom.8  \
# ...
